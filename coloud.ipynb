# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 visualizer = PointCloudVisualizer(file_path , exposure=500, gate_info=(0, 200))
#       6 # 方法1：使用Dash (交互性更强)
# ----> 7 visualizer.display_in_jupyter(mode="inline", height=600)
#
# File e:\Mingle\PythonCode\Coates\src\DataLoader\PointCloudVisualizer.py:152, in PointCloudVisualizer.display_in_jupyter(self, mode, width, height)
#     143 """
#     144 在Jupyter中显示点云可视化
#     145
#    (...)
#     149     height: 显示高度
#     150 """
#     151 if self.app is None:
# --> 152     self.create_dash_app(jupyter_mode=True)
#     154 self.app.run_server(mode=mode, width=width, height=height)
#
# File e:\Mingle\PythonCode\Coates\src\DataLoader\PointCloudVisualizer.py:108, in PointCloudVisualizer.create_dash_app(self, jupyter_mode)
#     101 lookup_table = {
#     102     "preset": "warm_to_cool",
# ...
